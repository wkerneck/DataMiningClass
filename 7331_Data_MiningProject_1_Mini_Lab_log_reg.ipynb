# %% [markdown]
# # ![.right](https://lh6.ggpht.com/wUrTIhpHPVqw_VPCdhbSiF5TXlBlLyRHdH1gsII_y5NkgYKzbbj7cC2l6AGoVq-JN0U=w100 "MSDS 7331 Data Mining - Project 1")
#
#
# # Project: Analysis of NASA Workforce Data - Mini Lab
#
# ---
#
#
#
# # Team Members
#
# - Chris Woodard
# - Claire Chu
# - Nathan Mowat
# - Bill Kerneckel
#
# ---
#
#
# # Table of Contents
#
# - [Business Understanding](#bsu)
#
# - [Data Meaning Type](#dmt)
#
# - [Data Quality](#dq)
#
# - [Simple Statistics](#ss)
#
# - [Visualize Attributes](#va)
#
# - [Explore Joint Attributes](#eja)
#
# - [Explore Attributes and Class](#eac)
#
# - [New Features](#nf)
#
# - [Exceptional](#e)
#
# - [Conclusion](#c)
#
# - [Next Steps](#ns)
#
# - [SVM & Logistic Regression Modeling](#LR)
#
# - [Assess Logestic Regression Modle Performance](#ALRMP)
#
# - [Support Vector Machine](#SVM)
#
# - [Support Vector Explination](#SVE)
#
# - [Classification Comparison](#CC)
#
# - [Acknowledgement](#ak)
#
# - [Appendix](#a)
#
# <hr>
#
# <div id='bsu'/>
# # BUSINESS UNDERSTANDING
#
# ### Describe the purpose of the data:
# The National Aeronautics and Space Administration (NASA) was created by Congress in 1958 to explore space and push the boundaries of flight. NASA created the first job descriptions knowns as Position Descriptions (PDs) to identify what skill sets would be needed to design, execute, and oversee a plan to place person(s) aboard a human-rated expandable rocket to make the 6,164 mile journey from Earth to the Moon.  With the use of these PDs, NASA initiated collecting and inventorying personnel data on all employees hired.  This is the same process executed today that creates data which is molded into the strategies for hiring practices today.
#
# The data set our team will be examining is 3 years of workforce data collected by NASA from the years of 2006 to 2008. NASA operated several missions including Space Station, Earth and Planetary Sciences, Aeronautical Research and Robotics during this time.  Our selected data set is a catalog of personnel data of the type of skills required to successfully carry out these missions.
#
# The available data from NASA is expansive and almost infinte.  After some deliberation, we decided to focus our exploration on data on the years 2006-2008. Our data set was built from three (3) excel files exported from the NASA Human Resources Agency database. Each excel file is one annual year of data. The data was retrieved on active employees and exported to Excel using the SQL queries documented below.
#
# ### Proposed outcomes
# Our team will work to investigate the nuances of past hires in the NASA HR agency with the aid of statistical tools (including Principle Component Analysis) to establish a predictive model for optimal future workforce demand. Our original query contained close to 50 atttributes. We hypothesize that gender, salary, grade, education level, promotion, hire date, diversity and the total number of new hires could possibly be predictors for need at specific paygrades. We are documenting the cleaning and exploration of years 06, 07 and 08.  Subsequent projects could include the concurrent seven (7) years of data.  This information may become part of the dataset and/or part of the cross validation data. As a team, we want to produce reproducible code that will help us create useful inferences regarding attributes within NASA Human Resources agency data. Successful predictions will be confirmed through cross validation with the remaining years of data.

# %% [markdown]
# <div id='dmt'/>
# # DATA MEANING TYPE
#
# ### Defining the variables
# Listed below are the column names, column types and definitions of all columns used for this analysis. Original Dataset had more than 75 variables, we have trimmed it to include the following 47 attributes.
#
#
# |  Column Name  	|   Type   	|                       Definition                       	|
# |:-------------:	|:--------:	|:------------------------------------------------------:	|
# | Agency        	| varchar  	| Agency code identifier                                 	|
# | Bdyr          	| varchar  	| Birth year of employee                                 	|
# | Coopsch       	| varchar  	| Co-op student's school / university code               	|
# | Coopyr        	| varchar  	| Co-op's graduation year                                	|
# | Currgrddte    	| datetime 	| Co-op's expected graduation date                       	|
# | Dtystn_ind    	| char     	| Duty station code                                      	|
# | Dtystnname    	| varchar  	| Location in the U.S. (County) code                     	|
# | Edlev         	| char     	| Level of eduction code                                 	|
# | Eoddte        	| datetime 	| Employment start date                                  	|
# | Foulev        	| char     	| Fourth Completed level in College                      	|
# | Fousch        	| char     	| Code associated with School (College/University Table) 	|
# | Fouyr         	| char     	| Year attained                                          	|
# | Frscdte       	| datetime 	| Federal Retirement Service Complete date               	|
# | Fscdte        	| datetime 	| Federal Service Complete Date                          	|
# | Grade         	| char     	| Grade level of employee. 1-15                          	|
# | Hilev         	| char     	| First school Level                                     	|
# | Hisch         	| varchar  	| First school Code                                      	|
# | Hiyr          	| varchar  	| First school Graduation Year                           	|
# | Install       	| char     	| Center Code (72 = JSC)                                 	|
# | Lastpromodt   	| datetime 	| Last promotion date                                    	|
# | Loccde        	| varchar  	| Duty Station Code – Where the employee is located      	|
# | Nasattl       	| char     	| NASA Job Title                                         	|
# | NCC           	| varchar  	| NASA Class Code (Job Classification)                   	|
# | Nextwigdte    	| datetime 	| Next with in grade date.                               	|
# | Occode        	| varchar  	| Occupational Series Code                               	|
# | Opmtitle      	| varchar  	| OP Job Title                                           	|
# | Orga          	| varchar  	| Organization Code                                      	|
# | Orgabr        	| varchar  	| Organization Branch                                    	|
# | Orgadir       	| varchar  	| Organization Directorate                               	|
# | Orgadiv       	| varchar  	| Organization Division                                  	|
# | Orgasec       	| varchar  	| Organization Section                                   	|
# | Postenure     	| char     	| Position Tenure (P=Permanent T=Term)                   	|
# | Promontedte   	| datetime 	| Projected Promotion Date                               	|
# | Retoptdte     	| datetime 	| Retirement Optional Date                               	|
# | Rno           	| varchar  	| Race and National Origin Indicator                     	|
# | Seclev        	| varchar  	| Second Completed level in College                      	|
# | Secsch        	| varchar  	| Code associated with School (College/University Table) 	|
# | Secyr         	| varchar  	| Year attained                                          	|
# | Sex           	| varchar  	| Sex                                                    	|
# | Step_emp      	| varchar  	| Current step level of the Employee                     	|
# | Supind        	| varchar  	| Supervisor Indicator                                   	|
# | Suplev        	| varchar  	| The level of the supervisor.                           	|
# | Tenure        	| varchar  	| Type of position indicator                             	|
# | Time_in_grade 	| varchar  	| Years  in the current grade level                      	|
# | Typappt       	| varchar  	| Type of Appointment                                    	|

# %% [markdown]
# ### Excel Import to verify data
# <span style="color:red">
# NOTE: In order to run these files, you will need "NEW_NASA_2006.xls","NEW_NASA_2007.xls" and "NASA_2008.xls" as these are sensitive materials, please contact Bill Kerneckel for download.
# </span>

# %%
#load python libaries
import numpy as np
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as pl
import seaborn as sns
import glob
import sys
import os
import warnings
import ggplot
import datetime
import time

# %%
# %matplotlib inline

# %%
#load data file
data_file = pd.read_excel('/Users/wkerneck/desktop/NEW_NASA_2006.xlsx') 
data_file2 = pd.read_excel('/Users/wkerneck/desktop/NEW_NASA_2007.xlsx') 
data_file3 = pd.read_excel('/Users/wkerneck/desktop/NASA_2008.xlsx') 
#you'll have to change the file path to your working directory

#removing 1st row from datasets
data_file.drop(0, axis = 0,inplace = True)
data_file2.drop(0, axis = 0,inplace = True)
data_file3.drop(0, axis = 0,inplace = True)

#note: please be patient as this will take a few minutes to run

# %%
#combining dataframes 
df = [data_file, data_file2, data_file3]

cdf = pd.concat(df, axis=0, join='outer', join_axes=None, ignore_index=False,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True)
cdf.reset_index()
# Out:
#        index       Hist_yr   agency  bdyr coopsch coopyr  currgrddte  \
# 0          1          2006     NN51  1900     NaN    NaN  10/08/1989
# 1          2          2006     NN51  1980     NaN    NaN  09/22/2002
# 2          3          2006     NN23  1986     NaN    NaN  07/21/1996
# 3          4          2006     NN64  1994     NaN    NaN  04/17/2005
# 4          5          2006     NN72  2006     NaN    NaN  07/23/2006
# 5          6          2006     NN62  1972     NaN    NaN  12/01/1997
# 6          7          2006     NN51  1900     NaN    NaN  02/27/2000
# 7          8          2006     NN72  1986     NaN    NaN  04/26/1998
# 8          9          2006     NN51  1978     NaN    NaN  09/27/1987
# 9         10          2006     NN10  1987     NaN    NaN  05/14/2006
# 10        11          2006     NN62  1982     NaN    NaN  07/30/2000
# 11        12          2006     NN72  1976     NaN    NaN  09/29/1989
# 12        13          2006     NN22  1973     NaN    NaN  04/04/2004
# ...

# %% [markdown]
# <hr>
# <div id='dq'/>
# # DATA QUALITY

# %%
#lets see how many rows and columns there are 1st excel file
print("Total Rows, Columns: {0}".format(np.shape(cdf)))
# Out:
# Total Rows, Columns: (56272, 51)

# %%
#lets see the header columns and types.
#print(cdf.dtypes)
#print(cdf.info())

# %% [markdown]
# Data has been read into memory.

# %%
#let's check to see where the null values are.
#cdf.isnull().sum()
#variables with a large number of null will have to be removed

# %% [markdown]
# We can see the majority of the null values exist in the following categories.
#
# - AGENCY
# - COOPSCH
# - COOPYR
# - FOULEV
# - FOUYR
# - NASATTL
# - PROBENDDTE
# - PROMONTEDTE
# - SECLEV
# - SECSCH
# -------------
# - DTYSTN_IND
# - DTYSTNNAME
# - TYPAPPT
# - WORKSCH
#
# We removed the variables with the most null values as well as "dtystn_ind", "dtystnnname", "typpappt", and "worksch" to help streamline our dataset.

# %%
# dropping columns we are not using for the analysis
cdf.drop('agency', axis=1, inplace=True)
cdf.drop('coopsch', axis=1, inplace=True)
cdf.drop('coopyr', axis=1, inplace=True)
cdf.drop('dtystn_ind', axis=1, inplace=True)
cdf.drop('dtystnname', axis=1, inplace=True)
cdf.drop('edlev', axis=1, inplace=True)
cdf.drop('foulev', axis=1, inplace=True)
cdf.drop('fousch', axis=1, inplace=True)
cdf.drop('fouyr', axis=1, inplace=True)
cdf.drop('nasattl', axis=1, inplace=True)
cdf.drop('probenddte', axis=1, inplace=True)
cdf.drop('promontedte', axis=1, inplace=True)
cdf.drop('secsch', axis=1, inplace=True)
cdf.drop('seclev', axis=1, inplace=True)
cdf.drop('typappt', axis=1, inplace=True)
cdf.drop('worksch', axis=1, inplace=True)

# %%
cdf.head
# Out:
# <bound method DataFrame.head of             Hist_yr  bdyr  currgrddte      eoddte     frscdte      fscdte  \
# 1              2006  1900  10/08/1989  07/14/1991  07/14/1991  02/21/1978
# 2              2006  1980  09/22/2002  07/01/1990  07/01/1990  11/11/1977
# 3              2006  1986  07/21/1996  04/01/1985  04/01/1985  08/25/1978
# 4              2006  1994  04/17/2005  03/03/2005  03/03/2005  01/28/2001
# 5              2006  2006  07/23/2006  01/11/2004  01/11/2004  02/03/2004
# 6              2006  1972  12/01/1997  12/01/1997  12/01/1997  12/01/1997
# 7              2006  1900  02/27/2000  07/04/1999  07/04/1999  05/16/1975
# 8              2006  1986  04/26/1998  02/03/1991  02/03/1991  07/12/1983
# 9              2006  1978  09/27/1987  05/12/1997  05/12/1997  09/06/1983
# 10             2006  1987  05/14/2006  07/28/2002  07/28/2002  04/05/1993
# 11             2006  1982  07/30/2000  07/19/1982  07/19/1982  07/19/1982
# ...

# %% [markdown]
# ## Data Cleaning
# We found that some of our variables were classified incorrectly. We converted 'salary', 'time_in_grade', and 'suplev' to floats. We also noticed that the default birth-year was '1900' if no information was given. Because this skewed the results and having multiple 117 year-old people was unlikely, we decided to eliminate all observations that contained a birth-year of 1900.

# %%
cdf = cdf[cdf.bdyr != 1900]
cdf.salary = cdf.salary.astype(np.float64)
cdf.time_in_grade = cdf.time_in_grade.astype(np.float64)
cdf.suplev = cdf.suplev.astype(np.float64)
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56272 entries, 1 to 18800
# Data columns (total 35 columns):
# Hist_yr          56269 non-null object
# bdyr             56269 non-null object
# currgrddte       56147 non-null object
# eoddte           56266 non-null object
# frscdte          56266 non-null object
# fscdte           56266 non-null object
# grade            56266 non-null object
# hilev            56177 non-null object
# hisch            46543 non-null object
# hiyr             56266 non-null object
# install          56266 non-null object
# lastpromodte     56261 non-null object
# leqdte           45812 non-null object
# loccde           56266 non-null object
# ncc              56266 non-null object
# nextwigdte       45733 non-null object
# occode           56266 non-null object
# opmtitle         56266 non-null object
# orga             56266 non-null object
# orgabr           56266 non-null object
# orgadir          56266 non-null object
# ...

# %%
# converting bdyr column to age
now = datetime.datetime.now()
cdf['bdyr'] = cdf['bdyr'].apply(pd.to_numeric, errors='coerce') 
cdf['age'] = now.year - cdf['bdyr']

# %%
cdf['salary_range'] = pd.cut(cdf.salary,[0,50000,100000,135000, 150000],4,
                             labels=['Entry_Level','Jr_Level','Mid_Level', 'Mgmt_Level' ])

# %%
cdf.dropna(inplace=True)

# %%
# convert cdf variable back to "df" nomenclature
df = pd.DataFrame(cdf)

# %%
# Outputting the Header information of the first dataset (data_file)
df.head
# Out:
# <bound method NDFrame.head of       Hist_yr    bdyr  currgrddte     eoddte     frscdte      fscdte grade  \
# 2        2006  1980.0  09/22/2002 1990-07-01  07/01/1990  11/11/1977    15
# 3        2006  1986.0  07/21/1996 1985-04-01  04/01/1985  08/25/1978    11
# 6        2006  1972.0  12/01/1997 1997-12-01  12/01/1997  12/01/1997    14
# 8        2006  1986.0  04/26/1998 1991-02-03  02/03/1991  07/12/1983    15
# 10       2006  1987.0  05/14/2006 2002-07-28  07/28/2002  04/05/1993    15
# 11       2006  1982.0  07/30/2000 1982-07-19  07/19/1982  07/19/1982    14
# 13       2006  1973.0  04/04/2004 1990-10-01  10/01/1990  10/01/1990    15
# 16       2006  1980.0  07/14/2002 2000-11-05  11/05/2000  02/21/1989    13
# 18       2006  2003.0  11/27/2005 2003-11-17  11/17/2003  11/17/2003    12
# 21       2006  1999.0  07/15/2001 2001-07-15  07/15/2001  01/13/1988    14
# 24       2006  1995.0  10/15/2006 2006-10-15  10/15/2006  10/15/2006    12
# ...

# %%
#manipulate employee start date 'eoddte' to get 'service' variable
#convert 'eoddte' to series
df.eod = pd.Series(df['eoddte'])
#convert 'eoddte' series to 'eoddte' datetime
df['eoddte'] = pd.to_datetime(df.eod) 
print('EODDTE')
print('----------')
print(df.eoddte.head())
# Out:
# EODDTE
# ----------
# 2    1990-07-01
# 3    1985-04-01
# 6    1997-12-01
# 8    1991-02-03
# 10   2002-07-28
# Name: eoddte, dtype: datetime64[ns]

# %%
#convert eod to be just the year
df['eodyr'] = df['eoddte'].map(lambda x: x.year)
print('EODYR')
print('----------')
print(df.eodyr.head())
# Out:
# EODYR
# ----------
# 2     1990
# 3     1985
# 6     1997
# 8     1991
# 10    2002
# Name: eodyr, dtype: int64

# %%
#convert high school graduation year "hiyr" to be numeric
df['hiyr'] = df['hiyr'].apply(pd.to_numeric, errors='coerce')
#df.hiyr.describe()
#after looking at a crosstab, we can see that there are a lot of "high school graduation year: 0"
#this is a data entry error, let's remove these entries...
df = df[df.hiyr != 0]
pd.crosstab(index=df["hiyr"],columns="hiyr")
#now the 0 entries have been removed

#subtract employee hire date from high school graduation date to get exprience
df['experience'] = df['eodyr'] - df['hiyr']

print('EXPERIENCE')
print('----------')
print(df.experience.head())
#negative numbers should be expected since some low level positions are filled by high school students
# Out:
# EXPERIENCE
# ----------
# 2     10
# 3     -1
# 6     25
# 8      5
# 10    15
# Name: experience, dtype: int64

# %%
#get the 'service' variable by subtracting current date from hire date
import time
from datetime import date
today = date.today()
df['service'] = today - df['eoddte']

print('SERVICE')
print('----------')
print(df.service.head())
# Out:
# SERVICE
# ----------
# 2     9730 days
# 3    11647 days
# 6     7020 days
# 8     9513 days
# 10    5320 days
# Name: service, dtype: timedelta64[ns]

# %%
#generate retirement potential by subtracting retirement eligibility date from todays date  
#convert retoptdte to series for conversion to datetime format
df.retoptdte = pd.Series(df['retoptdte'])
#convert 'retoptdte' series to 'eoddte' datetime
df['retoptdte'] = pd.to_datetime(df.retoptdte) 

print('RETOPTDTE')
print('----------')
print(df.retoptdte.head())
# Out:
# RETOPTDTE
# ----------
# 2    2012-02-18
# 3    2014-05-14
# 6    2005-05-03
# 8    2020-09-25
# 10   2015-06-30
# Name: retoptdte, dtype: datetime64[ns]

# %%
#generate 'retpot' variable
df['retpot'] = today - df['retoptdte']

print('RETPOT')
print('----------')
print(df.retpot.head())

#negative numbers should be expected since it represents employees who are not elligable for retirement yet
# Out:
# RETPOT
# ----------
# 2     1828 days
# 3     1012 days
# 6     4310 days
# 8    -1314 days
# 10     600 days
# Name: retpot, dtype: timedelta64[ns]

# %% [markdown]
# <hr>
#
# <div id='ss'/>
# # SIMPLE STATISTICS

# %%
df.describe()
# Out:
#                bdyr          hiyr         salary        suplev  time_in_grade  \
# count  37412.000000  37412.000000   37412.000000  37412.000000   37412.000000
# mean    1990.833690   1990.833690   99117.174837     33.275393      57.436918
# std        9.232588      9.232588   25696.891331      2.204069      49.649797
# min     1949.000000   1949.000000   20687.000000      1.000000       0.100000
# 25%     1985.000000   1985.000000   83949.000000     34.000000      15.520000
# 50%     1990.000000   1990.000000  101652.000000     34.000000      43.620000
# 75%     1998.000000   1998.000000  117334.000000     34.000000      86.360000
# max     2011.000000   2011.000000  149000.000000     38.000000     286.040000
#
#                 age         eodyr    experience                    service  \
# count  37412.000000  37412.000000  37412.000000                      37412
# mean      26.166310   1994.105608      3.271918  8234 days 05:09:30.041697
# ...

# %% [markdown]
# We now have 10 columns of meaningful numeric data to analyze.

# %%
df_grouped = df.groupby(by=['grade','sex'])
print (df_grouped.describe().transpose())
# Out:
# grade            10                                                        \
# sex               F
#               count                       mean                        std
# age              26                    25.5769                    8.31468
# bdyr             26                    1991.42                    8.31468
# eodyr            26                    1991.04                    7.73812
# experience       26                  -0.384615                    11.3387
# hiyr             26                    1991.42                    8.31468
# retpot           26   233 days 18:27:41.538461  2382 days 15:37:19.089815
# salary           26                    58980.7                    3925.35
# service          26  9376 days 17:32:18.461538  2771 days 09:09:23.876972
# suplev           26                         34                          0
# time_in_grade    26                    44.2996                    38.1548
#
# ...

# %%
df_grouped = df.groupby(by=['grade','sex'])
df_imputed = df_grouped.transform(lambda grp: grp.fillna(grp.median()))
df_imputed[['grade','sex']] = df[['grade','sex']]
print (df_imputed.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37412 entries, 2 to 18798
# Data columns (total 22 columns):
# Hist_yr          37412 non-null object
# bdyr             37412 non-null float64
# hilev            37412 non-null object
# hiyr             37412 non-null int64
# install          37412 non-null object
# ncc              37412 non-null object
# occode           37412 non-null object
# rno              37412 non-null object
# salary           37412 non-null float64
# secyr            37412 non-null object
# step_emp         37412 non-null object
# supind           37412 non-null object
# suplev           37412 non-null float64
# tenure           37412 non-null object
# time_in_grade    37412 non-null float64
# age              37412 non-null float64
# eodyr            37412 non-null int64
# experience       37412 non-null int64
# service          37412 non-null float64
# retpot           37412 non-null float64
# grade            37412 non-null object
# ...

# %% [markdown]
# We decided to fill all null values with the column median. We felt that since the errors were likely related to data entry, it would be acceptable to replace the null values with the median.

# %% [markdown]
# <hr>
#
# <div id='va'/>
# # VISUALIZE ATTRIBUTES

# %%
from pandas.tools.plotting import scatter_matrix
ax = scatter_matrix(df, figsize=(15, 10), diagonal='kde')
#show()

# %% [markdown]
# According to the scatter plot above, we noticed that the time in grade is skewed to the right. We also note that the "eodyr" or hire date is bimodal indicating that there were two positive hiring trends around 1990 and 2008. This makes sense since the 1980s and 1990s focused on shuttle launching. Around the 2000, we saw the challenger crash and NASA eventually closed the shuttle program due to safety reasons. In the mid to late 2000s, NASA ramped up to accomodate a new program called "Constellation".

# %%
# 2006 - 2008 Female and Male counts to generate pie chart
pd.crosstab(index=df["sex"],columns="count")
# Out:
# col_0  count
# sex
# F      12532
# M      24880

# %%
# Proportion of Males to Females in 2006 - 2008 (Pie Graph)
from pylab import *
 
# make a square figure and axes
figure(1, figsize=(6,6))
ax = axes([0.1, 0.1, 0.8, 0.8])

# The slices will be ordered and plotted counter-clockwise.
labels = 'Males', 'Females'
fracs = [24880, 12532]

pie(fracs, labels=labels,
                autopct='%1.1f%%', shadow=False, startangle=160)

title('Proportion of Males to Females in 2006-2008', bbox={'facecolor':'0.9', 'pad':5})

show()

# %% [markdown]
# We can see that Males outnumber Females 66% to 34%.

# %%
# Employees by Grade for 2006 - 2008
pd.crosstab(index=df["salary_range"],columns="count")
# Out:
# col_0         count
# salary_range
# Entry_Level    1807
# Jr_Level      16268
# Mid_Level     16866
# Mgmt_Level     2471

# %%
# paygrades by Percentages in 2006 - 2008
figure(1, figsize=(6,6))
ax = axes([0.2, 0.2, 1.3, 1.3])

# The slices will be ordered and plotted counter-clockwise.
labels = 'entry_level','jr_level', 'mid_level', 'mgmt_level'
fracs = [1807, 16268, 16866, 2471]
explode = [0.1,0,0,0.1]

pie(fracs, explode=explode, labels=labels,
                autopct='%1.1f%%', shadow=False, startangle=160)

title('Percentage of Employees by Position levels in 2006-2008', bbox={'facecolor':'0.9', 'pad':5})

show()

# %% [markdown]
# We can see from the pie chart that the majority of the workforce consists of junior level and mid level employees ranging from a salary of 100,000 - 135,000 dollars.

# %% [markdown]
# ---
# <div id='eac'/>
# # EXPLORE JOINT ATTRIBUTES

# %%
# Supervisor level per Grade for Males and Females in 2006 - 2008
import warnings
warnings.simplefilter('ignore', DeprecationWarning)

plt.style.use('ggplot')

df_grouped06 = df.groupby(by=['salary_range','sex'])
supervisor_level06 = df_grouped06.suplev.sum() / df_grouped06.suplev.count()
ax = supervisor_level06.plot(kind='barh')

title('Supervisor level per Salary Range for Males and Females 2006-2008', bbox={'facecolor':'0.6', 'pad':1})

show()

# %% [markdown]
# For 2006 through 2008, average position level per grade seems to be pretty consistent around the value of 34, does not have direct reports. We also see that they do not match the average work level of 34. We noticed in the data, the lower the average position level, the higher the grade. This makes sense since the higher the grade, the employee would likely have more responsibilities or supervisor duties. Furthermore, we see that there are fewer supervisor females than supervisor males, which makes sense looking at the female to male pie chart above.

# %%
## experience level graph goes here - parse dates
plt.style.use('ggplot')

df_grouped = df.groupby(by=['salary_range','sex'])
exp_per_grade = df_grouped.experience.sum() / df_grouped.experience.count()
ax = exp_per_grade.plot(kind='bar'); plt.axhline(0, color='k')

title('Average Experience per Salary Range for Males and Females (in years)', bbox={'facecolor':'0.8', 'pad':1})

show()

# %% [markdown]
# It is interesting to note that entry level employees have negative experience. This makes sense since the variable is calculated by subtracting the employee start date from high school graduation year. This means that most entry level employees have not graduated from high school yet. It is also interesting to see that Management level females have more experience than their male counterparts.

# %%
# Time per Grade Level for Males and Females from 2006 - 2008 (in Months))
plt.style.use('ggplot')

df_grouped = df.groupby(by=['salary_range','sex'])
time_per_grade = df_grouped.time_in_grade.sum() / df_grouped.time_in_grade.count()
ax = time_per_grade.plot(kind='bar')

title('Time per Salary Range for Males and Females from 2006 - 2008 (in Months)', bbox={'facecolor':'0.8', 'pad':1})

show()

# %% [markdown]
# Given that this is a male dominated agency, it is interesting to note that females in entry level and management level positions spend more time in their positions. Is it possible that for these positions, that males are more likely to get promoted? We will have to investigate further.

# %%
ax = sns.violinplot(x="salary_range", y="time_in_grade", data=df)
show(ax)
print(ax)
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# Based on the range, we can see that entry level only goes from just below 0 to just over 200; management level goes from 0 to over 300. The distribution for entry level shows that a majority of the entry level spend under 50 months in their grade. This makes sense since we assume that entry level positions are granted promotions often. This makes sense since people are spending more and more time in their grade as the salary range increases.

# %%
# Breakout of Race and national origin from 2006-2008
figure(1, figsize=(6,6))
ax = axes([0.1, 0.1, 1.0, 1.0])

# The slices will be ordered and plotted counter-clockwise.
# Key:
# 1 - White, 100 = Black or African American, 1000 = Asian, 10000 = American Indian or Alaskan Native, 100000 = Hispanic or Latino
labels = 'White', 'Black or African American', 'Asian','Hispanic or Latino', 'American Indian or Alaskan Native', 'Other'
fracs = [14200, 2168, 1139,947, 156, 120 ]
explode = [0,0,0,0,0.1,0.1]

pie(fracs, explode=explode, labels=labels,
                autopct='%1.1f%%', shadow=False, startangle=90)

title('Proportion of Ethnic Groups in the Workforce in 2006-2008', bbox={'facecolor':'0.9', 'pad':5})

show()

# %% [markdown]
# For this time period, we can see that the workforce is overwhelmingly white. This makes sense if we look at the census data for the US around this time. In 2010, census.gov (http://www.census.gov/prod/cen2010/briefs/c2010br-02.pdf) reports that white americans make up about 72% of the American population. Proportionally, it seems that NASA workforce diversity mirrors that of the US. Additionally, since we know that NASA primiarly hires engineers and the diversity of graduating engineers are primarily white Americans, this proves consistent.

# %%
from contextlib import suppress
with suppress(Exception):
    sns.set(style="white")
# create a plot grid
    g = sns.PairGrid(df[['age','salary']], diag_sharey=False)
    g.map_lower(sns.kdeplot, cmap="Blues_d") # use joint kde on the lower triangle
    g.map_upper(plt.scatter) # scatter on the upper
    g.map_diag(sns.kdeplot, lw=3) # kde histogram on the diagonal
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-595f09163c2e> in <module>()
# ----> 1 from contextlib import suppress
#       2 with suppress(Exception):
#       3     sns.set(style="white")
#       4 # create a plot grid
#       5     g = sns.PairGrid(df[['age','salary']], diag_sharey=False)
#
# ImportError: cannot import name suppress

# %% [markdown]
#
# ---
# <div id='eac'/>
# # EXPLORE ATTRIBUTES AND CLASS

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

show()

# %% [markdown]
# Based on the correlation heat map, we can see that salary is negatively correlated with birth year, high school graduation date, and hire date. This makes sense since these categories are time related. As the years increase (more recent) the less experience you have. In fact, we found that there were employees that had "negative" experience because they had not graduated from high school yet.

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula="salary ~ bdyr + hiyr + suplev + time_in_grade + age + eodyr + experience", data=df).fit()
print (result.params)
print (result.summary())
# Out:
# Intercept           0.796752
# bdyr               73.670418
# hiyr               73.670418
# suplev          -2751.449286
# time_in_grade      44.925028
# age              1533.377668
# eodyr             -72.655926
# experience       -146.326345
# dtype: float64
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     5747.
# Date:                Sun, 19 Feb 2017   Prob (F-statistic):               0.00
# Time:                        20:57:53   Log-Likelihood:            -4.2401e+05
# No. Observations:               37412   AIC:                         8.480e+05
# Df Residuals:                   37407   BIC:                         8.481e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# At the onset, we can see from our prelimiary regression, if we were trying to predict salary, our variables do not explain enough of the data with an r-squared of 0.381. By looking at the coefficients, we can see that supervisor level and time_in_grade are the most pertinent variables. As the error points out, there are strong multicollinearity problems. This makes sense since we use bdyr to calculate age and the hiyr/eoddyr to calculate experience.

# %% [markdown]
# ---
#
# <div id='nf'/>
# # NEW FEATURES

# %% [markdown]
# Based on our correlation graph and our preliminary regression, we should look into predicting another variable. Looking at the dataset, it would make more sense to try to predict the total number of employees from year to year. How should we do this? We need to get another variable that shows the total number of employees for each year. This should be easy to generate by taking the counts for each year of data.

# %%
df['Hist_yr'] = df['Hist_yr'].astype(int)
df_yrgroup = df.groupby(by=['Hist_yr'])
print (df_yrgroup.describe())
# Out:
#                         age          bdyr         eodyr    experience  \
# Hist_yr
# 2006    count  12136.000000  12136.000000  12136.000000  12136.000000
#         mean      26.746292   1990.253708   1993.157301      2.903593
#         std        9.165330      9.165330      9.027864      8.738782
#         min        7.000000   1949.000000   1957.000000    -34.000000
#         25%       20.000000   1984.000000   1987.000000     -2.000000
#         50%       27.000000   1990.000000   1991.000000      1.000000
#         75%       33.000000   1997.000000   2001.000000      8.000000
#         max       68.000000   2010.000000   2006.000000     40.000000
# 2007    count  12454.000000  12454.000000  12454.000000  12454.000000
#         mean      26.184519   1990.815481   1994.103902      3.288421
#         std        9.209797      9.209797      9.205766      8.982070
#         min        6.000000   1950.000000   1959.000000    -34.000000
# ...

# %% [markdown]
# We can see from the output above that there are
# 12136 employees for 2006,
# 12454 employees for 2007,
# 12822 employees for 2008.

# %% [markdown]
# ---
# <div id='c'/>
# # CONCLUSION
#
# Comparing from 2006 thru 2008 NASA Human Resources agency data, there are a few important things we can immediately notice. First, NASA is a male dominated agency. Males outnumber females almost 2 to 1. That being said, for our next project, we may have to pull random samples from the dataset that guarantees an equal number of males and females for analysis. That being said, we tried to offset this issue by using the average for each variable grouped by the gender class. After breaking out the data into four salary ranges, $50,000, $100,000, $135,000, and $150,000, we found that most of the NASA employees are junior level and mid level. Once we compared the Supervisor level per salary range, we found that the supervisor level is negatively correlated with salary range, ie. the higher the supervisor level value, the lower the salary range. We noticed some anomalies in the average experience per salary range when we looked at the two genders. This was also reflected in the time per salary range comparison by gender. Low level employees and management level employees. We plan to investigate this further in subsequent projects.
#
# Looking at the correlation heat mat and the preliminary OLS regression, we know that our data will probably not be a good predictor for salary, but we plan to fix that by instead investigating how hiring is affected by the variables developed in this notebook.
#
# ---
# <div id='ns'/>
# # NEXT STEPS
#
# As a team, we would like to explore the additional variable of total workforce by year. Using the variables we explored in this dataset like salary, age, experience, retirement potential, and years of service we hope to predict the size of the workforce for future years. Moving forward we hope to use Principle Component Analysis to establish a predictive model for the next years workforce planning demand using the remining 8 years of data both as part of the dataset and as part of the cross validation data.
#
# ---
# <div id='LR'/>
# # MINI-LAB: SVM & LOGISTIC REGRESSION MODELING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37412 entries, 2 to 18798
# Data columns (total 41 columns):
# Hist_yr          37412 non-null int64
# bdyr             37412 non-null float64
# currgrddte       37412 non-null object
# eoddte           37412 non-null datetime64[ns]
# frscdte          37412 non-null object
# fscdte           37412 non-null object
# grade            37412 non-null object
# hilev            37412 non-null object
# hisch            37412 non-null object
# hiyr             37412 non-null int64
# install          37412 non-null object
# lastpromodte     37412 non-null object
# leqdte           37412 non-null object
# loccde           37412 non-null object
# ncc              37412 non-null object
# nextwigdte       37412 non-null object
# occode           37412 non-null object
# opmtitle         37412 non-null object
# orga             37412 non-null object
# orgabr           37412 non-null object
# orgadir          37412 non-null object
# ...

# %%
# creating new dataframe. Keeping original seperate.
DF_NoT = df

# %%
# perform one-hot encoding of the categorical data "salary_range"
tmp_df = pd.get_dummies(df.salary_range,prefix='salary_range')
tmp_df2 = pd.get_dummies(df.rno,prefix='rno')

DF_NoT = pd.concat((df,tmp_df),axis=1) # add back into the dataframe
DF_NoT = pd.concat((DF_NoT,tmp_df2),axis=1)

# %%
# Delete time/dates - can't be used in L-Regression
del DF_NoT['eoddte']
del DF_NoT['retoptdte']
del DF_NoT['salary_range']
del DF_NoT['currgrddte']
del DF_NoT['frscdte']
del DF_NoT['fscdte']
del DF_NoT['hisch']
del DF_NoT['leqdte']
del DF_NoT['loccde']
del DF_NoT['ncc']
del DF_NoT['opmtitle']
del DF_NoT['occode']
del DF_NoT['orga']
del DF_NoT['orgabr']
del DF_NoT['orgadir']
del DF_NoT['orgadiv']
del DF_NoT['orgasec']
del DF_NoT['postenure']
del DF_NoT['tenure']
del DF_NoT['supind']
del DF_NoT['suplev']
del DF_NoT['rno']
del DF_NoT['rno_000010']  
del DF_NoT['rno_100100'] 
del DF_NoT['rno_100001'] 
del DF_NoT['rno_100010'] 
del DF_NoT['rno_100101'] 
del DF_NoT['rno_100000'] 
del DF_NoT['rno_011000'] 
del DF_NoT['rno_001101'] 
del DF_NoT['rno_010001'] 
del DF_NoT['rno_010101'] 
del DF_NoT['rno_001100'] 
del DF_NoT['rno_010000'] 
del DF_NoT['rno_010100'] 
del DF_NoT['rno_001001'] 
del DF_NoT['rno_001000'] 
del DF_NoT['rno_000101'] 
del DF_NoT['rno_000100'] 
del DF_NoT['rno_000011'] 
del DF_NoT['rno_101000'] 
del DF_NoT['rno_101101'] 
del DF_NoT['rno_110000'] 
del DF_NoT['rno_110001'] 
del DF_NoT['rno_110101'] 
del DF_NoT['rno_111111']

# %%
today = date(2008, 12, 31) #modify if more datasets are added
DF_NoT.service = DF_NoT.service / np.timedelta64(1, 'D')
DF_NoT.retpot = DF_NoT.retpot / np.timedelta64(1, 'D')

# %%
DF_NoT.lastpromodte = pd.Series(DF_NoT['lastpromodte'])
#convert 'eoddte' series to 'eoddte' datetime
DF_NoT['lastpromodte'] = pd.to_datetime(DF_NoT.lastpromodte) 
DF_NoT['lastpromodte'] = today - DF_NoT['lastpromodte']

# %%
#removing the day to calculate a number
DF_NoT.lastpromodte = DF_NoT.lastpromodte / np.timedelta64(1, 'D')

DF_NoT.nextwigdte = pd.Series(DF_NoT['nextwigdte'])
DF_NoT['nextwigdte'] = pd.to_datetime(DF_NoT.nextwigdte) 
DF_NoT['nextwigdte'] = today - DF_NoT['nextwigdte']
DF_NoT.nextwigdte = DF_NoT.nextwigdte / np.timedelta64(1, 'D')

DF_NoT.retdiscdte = pd.Series(DF_NoT['retdiscdte'])
DF_NoT['retdiscdte'] = pd.to_datetime(DF_NoT.retdiscdte) 
DF_NoT['retdiscdte'] = today - DF_NoT['retdiscdte']
DF_NoT.retdiscdte = DF_NoT.retdiscdte / np.timedelta64(1, 'D')

# %%
DF_NoT['IsMale'] = DF_NoT.sex=='M' 
DF_NoT.IsMale = DF_NoT.IsMale.astype(np.int)
del DF_NoT['sex']

# %%
from sklearn.cross_validation import ShuffleSplit
DF_Reg = DF_NoT
# we want to predict the X and y data as follows:
if 'salary_range_Jr_Level' in DF_Reg: # Choose a binary variable to predict / or go create one
    y = DF_Reg['salary_range_Jr_Level'].values # get the labels we want
    del DF_Reg['salary_range_Jr_Level'] # get rid of the class label
    X = DF_Reg.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n=num_instances,
                         n_iter=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(37412, n_iter=3, test_size=0.2, random_state=None)

# %%
# run logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt

# first we create a reusable object
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None) # get object

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object: 
   
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  
    y_hat = lr_clf.predict(X_test)

    # print accuracy for confusion matrix
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)

# %% [markdown]
# ---
#
# <div id='alrmp'>
# # ASSESS LOGISTIC REGRESSION MODEL PERFORMANCE

# %%
print("====Iteration",iter_num," ====")
print("accuracy", acc )
print("confusion matrix\n",conf)
iter_num+=1
# Out:
# ('====Iteration', 0, ' ====')
# ('accuracy', 0.98730455699585729)
# ('confusion matrix\n', array([[4128,   67],
#        [  28, 3260]]))
# ('====Iteration', 1, ' ====')
# ('accuracy', 0.87785647467593209)
# ('confusion matrix\n', array([[3807,  381],
#        [ 533, 2762]]))
# ('====Iteration', 2, ' ====')
# ('accuracy', 0.96431912334625147)
# ('confusion matrix\n', array([[4063,  149],
#        [ 118, 3153]]))

# %%
# interpret the weights before normalization

weights = lr_clf.coef_.T 
variable_names = DF_NoT.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
# Out:
# (u'Hist_yr', 'has weight of', 0.031932852936215603)
# (u'bdyr', 'has weight of', -0.005134458651950986)
# (u'grade', 'has weight of', 1.4672341589818521)
# (u'hilev', 'has weight of', -0.026949907040110164)
# (u'hiyr', 'has weight of', -0.005134458651950986)
# (u'install', 'has weight of', 0.0014178877353613806)
# (u'lastpromodte', 'has weight of', 0.00035143207368509247)
# (u'nextwigdte', 'has weight of', -0.00043149076597889688)
# (u'retdiscdte', 'has weight of', -3.953002854879207e-05)
# (u'salary', 'has weight of', -0.00017450343738664449)
# (u'secyr', 'has weight of', -8.0754063186353518e-06)
# (u'step_emp', 'has weight of', 0.12226561723951085)
# (u'time_in_grade', 'has weight of', -0.00098479315325598004)
# ('age', 'has weight of', -0.008657583694042072)
# ('eodyr', 'has weight of', -0.022620386584149749)
# ('experience', 'has weight of', -0.017485927942676987)
# ('service', 'has weight of', -0.00018748026854622217)
# ('retpot', 'has weight of', 3.8604423708661837e-05)
# ...

# %% [markdown]
# ---
#
# <div id='WI'>
# # WEIGHTS INTERPERTATION

# %% [markdown]
# The weights are not interpretable because of the attributes. We will normalize the features and re-run the full regression model.

# %%
from sklearn.preprocessing import StandardScaler

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) 
# find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05) # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,DF_Reg.columns) # combine attributes
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# /Users/wkerneck/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/wkerneck/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/wkerneck/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ('accuracy:', 1.0)
# [[4241    0]
#  [   0 3242]]
# (u'Hist_yr', 'has weight of', -0.026159475527686098)
# (u'bdyr', 'has weight of', 0.067834129440855734)
# (u'grade', 'has weight of', 0.21687649762608108)
# (u'hilev', 'has weight of', -0.099874976013160352)
# ...

# %% [markdown]
# ---
#
# <div id='NWI'>
# # NORMALIZE WEIGHT INTERPRETATION

# %% [markdown]
# These weights are what is expected due how the Goverment controls variability with hiring and promotion schedules. According to these results, the largest wieght we can see is the variable title 'salary_range_Mid_Level' with a value of <strong>-4.621035350746709</strong>. As a whole, these weights are relatively low. We might want to investigate Step-Wise or Lasso varaible selection methods. Our dependent variable was 'salary_range_Jr_Level' and we acheived strong categorization.

# %%
if 'salary_range_Jr_Level' in DF_Reg: # Choose a binary variable to predict / or go create one
    y = DF_Reg['salary_range_Jr_Level'].values # get the labels we want
    del DF_Reg['salary_range_Jr_Level'] # get rid of the class label
    X = DF_Reg.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 1
num_instances = len(y)
cv_object2 = ShuffleSplit(n=num_instances,
                         n_iter=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object2)
# Out:
# ShuffleSplit(37412, n_iter=1, test_size=0.2, random_state=None)

# %%
for train_indices, test_indices in cv_object2: 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)
# Out:
# /Users/wkerneck/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/wkerneck/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ---
# <div id='SVM'/>
# # SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='linear', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# ('accuracy:', 1.0)
# [[4187    0]
#  [   0 3296]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (354, 23)
# (354,)
# [223 131]

# %% [markdown]
# ---
#
# <div id='sve'>
# # SUPPORT VECTOR EXPLANATION

# %% [markdown]
# The datasets we were working with was clearly classified. Binary groups were explicitly clear. Majority of the data seemed catagorical which made it easy for classification.

# %% [markdown]
# ---
#
# <div id='CC'>
# # CLASSIFICATION COMPARISON

# %% [markdown]
# In the contents of this dataset and for this lab, support vector machine (SVM) appears to be more accurate. Normally this would be an example of "overfiiting" but knowing where this dataset came from and how the U.S. Goverment Federal salaries are determined by congress and pay increases are set by a days-in-service schedule. See OPM General Pay Schedule: https://www.opm.gov/policy-data-oversight/pay-leave/pay-systems/general-schedule/. Since the "grade" variable and the "time in service" variable are used to determine salary, we suspect that including them in this logistic regression is giving us some results with multicolinearity. If we had more time, we would remove these variables and tune the regession again.

# %% [markdown]
# ---
# <div id='a'/>
# # ACKNOWLEDGEMENTS
#
# - Office of Personnel Management (OPM)
# - National Aeronautics and Space Administration (NASA)
# - NASA Johnson Space Center (JSC)

# %% [markdown]
# ---
# # APPENDIX
#
# ### SQL Query
#
# A SQL query was written to pull the needed data from NASA's Human Resources Agency Workforce Microsoft SQL Database. The SQL query retrieves records for only active employee by calendar year.
#
# ```
# SELECT
#     [agency]
#     ,convert(varchar(10),[apptntedte], 101) as apptntedte
#     ,[bdyr]
#     ,[citizen]
#     ,[coopfld]
#     ,[cooplev]
#     ,[coopsch]
#     ,[coopyr]
#     ,convert(varchar(10),[currgrddte], 101) as currgrddte
#     ,[dlrlimit]
#     ,[dtystn_ind]
#     ,[dtystnname]
#     ,[dtysts]
#     ,[edlev]
#     ,convert(varchar(10),[eoddte], 101) as eoddte
#     ,[finstm]
#     ,[foufld]
#     ,[foulev]
#     ,[fousch]
#     ,[fouyr
#     ,convert(varchar(10),[frscdte], 101) as frscdte
#     ,convert(varchar(10),[fscdte], 101) as fscdte
#     ,convert(varchar(10),[fscdte_enhanced], 101) as fscdte_enhanced
#     ,[grade]
#     ,[graderetn]
#     ,[hifld]
#     ,[hilev]
#     ,[hisch]
#     ,[hiyr]
#     ,[hrlimit]
#     ,[install]
#     ,[install_calc]
#     ,convert(varchar(10),[lastpromodte], 101) as lastpromodte
#     ,convert(varchar(10),[leqdte], 101) as leqdte
#     ,[loccde]
#     ,convert(varchar(10),[lwopntedte], 101) as lwopntedte
#     ,[nasattl]
#     ,[ncc]
#     ,[ncc_old]
#     ,convert(varchar(10),[nextwigdte], 101) as nextwigdte
#     ,convert(varchar(10),[nscdte], 101) as nscdte
#     ,[occode]
#     ,[opmtitle]
#     ,[orga]
#     ,[orgabr]
#     ,[orgadir]
#     ,[orgadiv]
#     ,[orgasec]
#     ,[poi]
#     ,[poscrit]
#     ,[postenure]
#     ,[prd]
#     ,[probenddte]
#     ,convert(varchar(10),[probenddte], 101) as probenddte
#     ,[projpromo]
#     ,convert(varchar(10),[promontedte], 101) as promontedte
#     ,convert(varchar(10),[retdiscdte], 101) as retdiscdte
#     ,convert(varchar(10),[retoptdte], 101) as retoptdte
#     ,[rno]
#     ,convert(varchar(10),[rscdte], 101) as rscdte
#     ,[rtd]
#     ,[secfld]
#     ,[seclev]
#     ,[secsch]
#     ,[secyr]
#     ,[sex]
#     ,[spid]
#     ,[step_emp]
#     ,[stepretn]
#     ,[super_diff]
#     ,[supind]
#     ,[suplev]
#     ,[tenure]
#     ,convert(varchar(10),[tenurebdte], 101) as tenurebdte
#     ,[time_in_grade]
#     ,[typappt]
#     ,[worksch]
# FROM [XXX].[XXX].[PerStat]
# WHERE dtysts in ('a','c','f','i','l','m','p','v','y')
# AND Hist_yr = 'ENTER 4 DIGIT YEAR'
# ```
